# %% [markdown]
# HW1:Trending YouTube Video Statistics
#
# Kaggle:https://www.kaggle.com/datasnaek/youtube-new
#
# 1. 你選的這組資料為何重要:
#
# youtube已成為每天必看之app，從當中學習如何登上熱門發燒榜之因素，包含標題內容，喜歡之群眾等因素。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集):
#
# youtube每日熱門排行榜。
# 3. 蒐集而來的資料型態為何:
#
# csv
# 4. 這組資料想解決的問題如何評估:
#
# 對於新進之youtuber可學習如何登上發燒榜之因素。

# %% [markdown]
# HW2:經營自由載客車隊
#
# 1. 核心問題為何:
#
# 每日地區、時段、節日，皆會有不同人數及需求客人，安排合理車數，避免供給失衡。
# 2. 資料從何而來:
#
# 收集各地區大眾交通上下車人數、與各公共場所或商場百貨人流量。
# 3. 蒐集而來的資料型態為何
#
# 數值、表格、地圖、圖表...。
# 4. 你要回答的問題，其如何評估
#
# 依據人潮數對應時間，分析評估應派車隊員工數。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    """
    請完成這個 Function 後往下執行
    """
    """
    計算 MSE
    Args:
        - y: 實際值
        - y_hat: 預測值
    Return:
        - mse: MSE
    """
    
    mse = sum(abs(y-y_hat)**2) /len(y)
    return mse
    
    
def mean_absolute_error(y, y_hat):
    """
    計算 MAE
    Args:
        - y: 實際值
        - y_hat: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - y_hat)) / len(y)
    return mae

##MAE = mean_absolute_error(y, y_hat)
##print("The Mean absolute error is %.3f" % (MAE))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 195.995
# The Mean absolute error is 11.608
